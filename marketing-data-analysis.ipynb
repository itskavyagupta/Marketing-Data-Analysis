# %%
#Problem Statement:

# You're a marketing analyst and you've been told by the Senior Marketing Manager that recent marketing campaigns have not
# been as effective as they were expected to be. You need to analyze the data set in order to understand this problem and
# propose data-driven solutions. You are required to solve the following questions to generate a report for your management.

# %%
# 1. Import necessary libraries and load the dataset and display random 5 samples. Check the info of the data
# and write your findings.

import numpy as np
import pandas as pd

df=pd.read_csv("marketing_data.csv")
df.sample(5)
# Out:
#         ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 1870  8017        1981    2n Cycle        Married  $51,111.00         1
# 1663  2853        1980  Graduation         Single  $51,766.00         1
# 71    5341        1962    2n Cycle       Divorced  $81,975.00         0
# 147   1407        1986       Basic        Married  $20,425.00         1
# 523   2173        1952  Graduation          Widow  $40,049.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 1870         1     6/19/14       83        22  ...                  3
# 1663         0     3/11/14       74        60  ...                  4
# 71           1      1/5/13        2       983  ...                  4
# 147          0    10/29/12        5         4  ...                  3
# 523          1    10/16/13       23        13  ...                  3
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# Observations inferred from the info of dataframe:

# 1. There are 2240 rows present.
# 2. There are 28 columns in the given dataset.

# 4. There are 2 data types present in the given dataset, which are: int and object.

# %%
# 2. Check the following using an appropriate method and write your findings
# i) Check how spread out or varied your data set is.
# ii) Check where the middle 50% of your data lies.
# iii) Check boundaries for the lower, middle and upper quarters of data.

df.describe().transpose()
# Out:
#                       count         mean          std     min      25%  \
# ID                   2240.0  5592.159821  3246.662198     0.0  2828.25
# Year_Birth           2240.0  1968.805804    11.984069  1893.0  1959.00
# Kidhome              2240.0     0.444196     0.538398     0.0     0.00
# Teenhome             2240.0     0.506250     0.544538     0.0     0.00
# Recency              2240.0    49.109375    28.962453     0.0    24.00
# MntWines             2240.0   303.935714   336.597393     0.0    23.75
# MntFruits            2240.0    26.302232    39.773434     0.0     1.00
# MntMeatProducts      2240.0   166.950000   225.715373     0.0    16.00
# MntFishProducts      2240.0    37.525446    54.628979     0.0     3.00
# MntSweetProducts     2240.0    27.062946    41.280498     0.0     1.00
# MntGoldProds         2240.0    44.021875    52.167439     0.0     9.00
# NumDealsPurchases    2240.0     2.325000     1.932238     0.0     1.00
# ...

# %%
# Observations inferred from the info of dataframe:

# i) The spread of the dataset can be inferred from 'std' values.
# ii) The middle 50% data can be found out by subtracting the value at 75% from the value at 25% for the
# particular column we want tp find the middle 50% data of.
# iii) The boundaries of lower quarter of data is: (value at 25%) - (value at min)
#      The boundaries of 1st middle quarter of data is: (value at 50%) - (value at 25%)
#      The boundaries of 2nd middle quarter of data is: (value at 75%) - (value at 50%)
#      The boundaries of upper quarter of data is: (value at max) - (value at 75%)

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
#renaming the 'Income' column to remove extra whitespaces

df.rename(columns = {' Income ':'Income'}, inplace = True)

# %%
# Converting the 'Income' values to type float.

df['Income']=df['Income'].str.replace(',','')
df['Income']=df['Income'].str.replace('$','')
df['Income']=df['Income'].str.replace(" ","")
df['Income']=df['Income'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# 3. Check for any missing values in the dataset and handle them using an appropriate method.

df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
# 'Income' column has null values. Filling the null values with the mean of the column.

df['Income'] = df['Income'].fillna(df['Income'].mean())
df.isnull().any()

#On checking for null again, we get a False for the 'Income' column as well now.
# Out:
# ID                     False
# Year_Birth             False
# Education              False
# Marital_Status         False
# Income                 False
# Kidhome                False
# Teenhome               False
# Dt_Customer            False
# Recency                False
# MntWines               False
# MntFruits              False
# MntMeatProducts        False
# MntFishProducts        False
# MntSweetProducts       False
# MntGoldProds           False
# NumDealsPurchases      False
# NumWebPurchases        False
# NumCatalogPurchases    False
# NumStorePurchases      False
# NumWebVisitsMonth      False
# AcceptedCmp3           False
# AcceptedCmp4           False
# AcceptedCmp5           False
# AcceptedCmp1           False
# AcceptedCmp2           False
# Response               False
# Complain               False
# Country                False
# dtype: bool

# %%
# 4. Check for any presence of special characters in any variables. If present, clean/replace and change the datatype
# of the variable if required.

import string
alphanum = string.ascii_letters+string.digits+string.whitespace

# Checking all the columns with the data type as 'object' for any special characters.

df.Education.str.strip(alphanum).astype(bool).any()
# Out:
# False

# %%
df.Marital_Status.str.strip(alphanum).astype(bool).any()
# Out:
# False

# %%
df.Dt_Customer.str.strip(alphanum).astype(bool).any()
# Out:
# True

# %%
df.Country.str.strip(alphanum).astype(bool).any()
# Out:
# False

# %%
# 'Dt_Customer' has special characters. Converting the column to datetime data type.

df['Dt_Customer']=df['Dt_Customer'].str.replace('-','/')
df['Dt_Customer']=df['Dt_Customer'].str.replace(" ","")
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'], format='%m/%d/%y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   datetime64[ns]
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# 5. The Marketing Manager wants to know the 'Age' of the customers. Extract the feature age from the given dataset
# and display the statistical summary of the age?

df['Year_Birth'] = pd.to_datetime(df['Year_Birth'], format='%Y')
df['age'] = (pd.to_datetime('now') - df['Year_Birth']).astype('m8[Y]')
df['age'].describe()
# Out:
# count    2240.000000
# mean       53.194196
# std        11.984069
# min        26.000000
# 25%        45.000000
# 50%        52.000000
# 75%        63.000000
# max       129.000000
# Name: age, dtype: float64

# %%
# 6. The Marketing manager wants to understand the total amount spent on various products so that we can find what
# percentage of the amount is spent on which product.
# a. Find out the total amount spent by a customer.
# b. Display the Percentage of the amount spent on Wines and other products.

df['total_amount'] = df["MntWines"] + df["MntFruits"] + df["MntMeatProducts"] + df["MntFishProducts"] + df["MntSweetProducts"] + df["MntGoldProds"]
df.head()

# A new column named 'total_amount' is added which shows the total amount spent by a customer on all products.
# Out:
#       ID Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826 1970-01-01  Graduation       Divorced  84835.0        0         0
# 1      1 1961-01-01  Graduation         Single  57091.0        0         0
# 2  10476 1958-01-01  Graduation        Married  67267.0        0         1
# 3   1386 1967-01-01  Graduation       Together  32474.0        1         1
# 4   5371 1989-01-01  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  AcceptedCmp3  AcceptedCmp4  \
# 0  2014-06-16        0       189  ...             0             0
# 1  2014-06-15        0       464  ...             0             0
# 2  2014-05-13        0       134  ...             0             0
# 3  2014-05-11        0        10  ...             0             0
# 4  2014-04-08        0         6  ...             1             0
#
#    AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain  Country  \
# ...

# %%
import matplotlib.pyplot as plt

df[df.columns[9:15]].sum().plot(kind='pie', ylabel=' ', autopct='%1.0f%%', title='Percentages of the total amount spent on Wines and other products', figsize=(11,11), table=True)
plt.show()

# Plotting a pie chart to display the percentage of the total amount spent on Wines and other products.

# %%
# 7. Being an Analyst understands the total number of purchases made through different channels which can help find
# the percentage these channels contribute.
# a. Find out the total purchases done by a customer through different channels.
# b. Display the percentage of the store and other channels’ contribution to the total purchases.

df['total_purchase'] = df["NumDealsPurchases"] + df["NumWebPurchases"] + df["NumCatalogPurchases"] + df["NumStorePurchases"]
df.head()

# A new column named 'total_purchases' is added which shows the total number of purchases done by a customer.
# Out:
#       ID Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826 1970-01-01  Graduation       Divorced  84835.0        0         0
# 1      1 1961-01-01  Graduation         Single  57091.0        0         0
# 2  10476 1958-01-01  Graduation        Married  67267.0        0         1
# 3   1386 1967-01-01  Graduation       Together  32474.0        1         1
# 4   5371 1989-01-01  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  AcceptedCmp4  AcceptedCmp5  \
# 0  2014-06-16        0       189  ...             0             0
# 1  2014-06-15        0       464  ...             0             0
# 2  2014-05-13        0       134  ...             0             0
# 3  2014-05-11        0        10  ...             0             0
# 4  2014-04-08        0         6  ...             0             0
#
#    AcceptedCmp1  AcceptedCmp2  Response  Complain  Country   age  \
# ...

# %%
df[df.columns[15:19]].sum().plot(kind='pie', ylabel=' ', autopct='%1.0f%%', title='Percentage of the store and other channels’ contribution to the total purchases', figsize=(11,11), table=True)
plt.show()

# Plotting a pie chart to display the percentage of the store and other channels’ contribution to the total purchases.

# %%
# 8. The marketing manager wants to understand the performance of different marketing campaigns. Find out which
# marketing campaign is most successful? Use suitable graphs for visualization.

df[df.columns[20:26]].sum().plot(kind='bar', xlabel='Campaign Number', ylabel='Number of times it was accpeted', title='Performance of various campaigns', figsize=(11,11), legend=False)
plt.show()

# %%
# Thus, as we can see from the chart, the most successful campaign was the last campaign.

# %%
# 9. The marketing manager wants to understand which products are performing the best and which are performing the
# least in terms of revenue. Being an analyst, analyse the data and plot a suitable graph to display a report on
# revenue generated by different products.

df[df.columns[9:15]].sum().plot(kind='area', title='Revenue generated by different products', figsize=(11,11))
plt.show()

# %%
# Thus, as we can see from the chart, the product which is performing the best is Wines and the least revenue
# generating product is Fruits.

# %%
# 10. The team wants to understand if there’s any pattern between the age of customers and the last campaign
# acceptance rate. Plot a suitable graph to visualize the distribution of the age with respect to customers who accepted
# the last campaign.

df.plot(kind='hist', x='Response', y='age')
plt.show()

# %%
# 11. The Chief Marketing specialist wants to visually see which Country has the most number of customers who
# accepted the last campaign. What is your approach?

df.groupby(['Country']).size().plot(kind = "barh")
plt.show()

# %%
# 12. Analyse visually and write your inferences about the relationship between the following:-
# i) Total amount spent Vs Dependents. (Dependents=['Kidhome']+['Teenhome'])
# ii) Total Purchases Vs Dependents.

df['Dependents']=df['Kidhome']+df['Teenhome']

# %%
df.groupby(['Dependents']).mean().plot(kind='line', y='total_amount')
plt.show()

# %%
df.groupby(['Dependents']).mean().plot(kind='line', y='total_purchase')
plt.show()

# %%
# 14. Understand the Education background of the customers who complained in the last 2 years. State the Education
# background of the customers who have registered the most number of complaints.

df.groupby("Education").agg({'Complain':'sum'}).sort_values('Complain', ascending=False)
# Out:
#             Complain
# Education
# Graduation        14
# 2n Cycle           4
# Master             2
# PhD                1
# Basic              0

# %%
# 15. Use features 'Total_amount_spent', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts' and,
# 'MntGoldProds' in x-axis and y-axis and plot the following plots.
# i) Plot a pairplot with hue as Response.
# ii) Plot a pairplot with hue as Education.
# iii) Plot a pairplot with hue as Marital Status and write your key observations.

import seaborn as sns

df1= df[['MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'total_amount', 'Response', 'Education', 'Marital_Status']].copy()
df1.head()
# Out:
#    MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# 0        104              379              111               189
# 1          5               64                7                 0
# 2         11               59               15                 2
# 3          0                1                0                 0
# 4         16               24               11                 0
#
#    MntGoldProds  total_amount  Response   Education Marital_Status
# 0           218          1190         1  Graduation       Divorced
# 1            37           577         1  Graduation         Single
# 2            30           251         0  Graduation        Married
# 3             0            11         0  Graduation       Together
# 4            34            91         1  Graduation         Single

# %%
sns.pairplot(df1, hue = 'Response')
plt.show()

# %%
sns.pairplot(df1, hue = 'Education')
plt.show()

# %%
sns.pairplot(df1, hue = 'Marital_Status')
plt.show()
